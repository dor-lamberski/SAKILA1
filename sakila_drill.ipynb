# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import sqlalchemy as sql
import datetime as dt
from datetime import datetime
import matplotlib.pyplot as plt

# %%
# 2. Connect to Sakila DB
engine = sql.create_engine('postgresql+psycopg2://app_student:$vaoNXn3^Rmm@hu-dm.postgres.database.azure.com:5432/sakila')

# %%
with engine.connect() as connection:
    actor_df = pd.read_sql_table('actor', connection)
    film_df = pd.read_sql_table('film', connection)
    film_actor_df = pd.read_sql_table('film_actor', connection)
    category_df = pd.read_sql_table('category', connection)
    film_category_df = pd.read_sql('film_category',connection)
    payment_df = pd.read_sql_table('payment', connection)
    customer_df = pd.read_sql_table('customer', connection)
    store_df = pd.read_sql_table('store', connection)
    inventory_df = pd.read_sql_table('inventory', connection)
    rental_df = pd.read_sql_table('rental', connection)
    address_df= pd.read_sql_table('address', connection)

# %%
actor_df.head()
# Out:
#    actor_id first_name     last_name             last_update
# 0         1   Penelope       Guiness 2013-05-26 14:47:57.620
# 1         2       Nick      Wahlberg 2013-05-26 14:47:57.620
# 2         3         Ed         Chase 2013-05-26 14:47:57.620
# 3         4   Jennifer         Davis 2013-05-26 14:47:57.620
# 4         5     Johnny  Lollobrigida 2013-05-26 14:47:57.620

# %%
film_df.head()
# Out:
#    film_id               title  \
# 0      133     Chamber Italian
# 1      345   Gables Metropolis
# 2      346  Galaxy Sweethearts
# 3      347     Games Bowfinger
# 4      348         Gandhi Kwai
#
#                                          description  release_year  \
# 0  A Fateful Reflection of a Moose And a Husband ...          2008
# 1  A Fateful Display of a Cat And a Pioneer who m...          2007
# 2  A Emotional Reflection of a Womanizer And a Pi...          2007
# 3  A Astounding Documentary of a Butler And a Exp...          2008
# 4  A Thoughtful Display of a Mad Scientist And a ...          2012
#
#    language_id  rental_duration  rental_rate  length  replacement_cost rating  \
# 0            1                7         4.99     117             14.99  NC-17
# 1            1                3         0.99     161             17.99     PG
# 2            1                4         4.99     128             13.99      R
# ...

# %%
film_actor_df.head()
# Out:
#    actor_id  film_id                last_update
# 0         1        1 2022-10-12 14:30:29.123178
# 1         1       23 2022-10-12 14:30:29.123178
# 2         1       25 2022-10-12 14:30:29.123178
# 3         1      106 2022-10-12 14:30:29.123178
# 4         1      140 2022-10-12 14:30:29.123178

# %%
category_df.head()
# Out:
#    category_id       name                last_update
# 0            1     Action 2022-10-12 14:30:07.869260
# 1            2  Animation 2022-10-12 14:30:07.869260
# 2            3   Children 2022-10-12 14:30:07.869260
# 3            4   Classics 2022-10-12 14:30:07.869260
# 4            5     Comedy 2022-10-12 14:30:07.869260

# %%
film_category_df.head()
# Out:
#    film_id  category_id                last_update
# 0        1            6 2022-10-12 14:30:33.560728
# 1        2           11 2022-10-12 14:30:33.560728
# 2        3            6 2022-10-12 14:30:33.560728
# 3        4           11 2022-10-12 14:30:33.560728
# 4        5            8 2022-10-12 14:30:33.560728

# %%
payment_df.sort_values(by='rental_id', ascending=True)
# Out:
#       payment_id  customer_id  staff_id  rental_id  amount  \
# 291        17793          416         2       1158    2.99
# 671        18173          516         2       1159    4.99
# 1897       19399          239         1       1160    4.99
# 939        18441          592         2       1163    6.99
# 1196       18698           49         1       1164    0.99
# ...          ...          ...       ...        ...     ...
# 5311       22814           14         1      16045    0.99
# 5897       23400           74         1      16046    0.99
# 6237       23740          114         1      16047    0.99
# 6147       23650          103         2      16048    8.99
# 3215       20718          393         2      16049    3.99
#
#                    payment_date
# 291  2022-07-18 21:21:59.996577
# 671  2022-07-18 21:23:39.996577
# 1897 2022-07-18 21:29:00.996577
# 939  2022-07-18 21:41:12.996577
# 1196 2022-07-18 21:44:52.996577
# ...                         ...
# ...

# %%
customer_df.head()
# Out:
#    customer_id  store_id first_name last_name  \
# 0          480         1      Corey    Hauser
# 1          524         1      Jared       Ely
# 2            3         1      Linda  Williams
# 3            4         2    Barbara     Jones
# 4            5         1  Elizabeth     Brown
#
#                                 email  address_id  activebool create_date  \
# 0     corey.hauser@sakilacustomer.org         485        True  2006-02-14
# 1        jared.ely@sakilacustomer.org         530        True  2006-02-14
# 2   linda.williams@sakilacustomer.org           7        True  2006-02-14
# 3    barbara.jones@sakilacustomer.org           8        True  2006-02-14
# 4  elizabeth.brown@sakilacustomer.org           9        True  2006-02-14
#
#                  last_update  active prefix  annual_income
# 0 2024-06-04 20:22:26.104493       1     ma           5854
# 1 2024-06-04 20:22:26.104493       1     ma          10197
# 2 2024-06-04 20:22:26.104493       1     ba          18949
# ...

# %%
store_df['staff_id'] =store_df['manager_staff_id']
store_df.head()
# Out:
#    store_id  manager_staff_id  address_id                last_update  staff_id
# 0         1                 1           1 2022-10-12 14:31:04.032191         1
# 1         2                 2           2 2022-10-12 14:31:04.032191         2

# %%
inventory_df.head()
# Out:
#    inventory_id  film_id  store_id                last_update
# 0             1        1         1 2022-10-12 14:30:46.561001
# 1             2        1         1 2022-10-12 14:30:46.561001
# 2             3        1         1 2022-10-12 14:30:46.561001
# 3             4        1         1 2022-10-12 14:30:46.561001
# 4             5        1         2 2022-10-12 14:30:46.561001

# %%
rental_df.head()
# Out:
#    rental_id         rental_date  inventory_id  customer_id return_date  \
# 0      11496 2021-07-15 15:16:03          2047          155         NaT
# 1      12222 2021-07-15 15:16:03          3949           22         NaT
# 2      12574 2021-07-15 15:16:03           177          317         NaT
# 3      12891 2021-07-15 15:16:03          2764          388         NaT
# 4      12901 2021-07-15 15:16:03          2799          180         NaT
#
#    staff_id                last_update
# 0         1 2022-10-12 14:29:28.945439
# 1         1 2022-10-12 14:29:28.945439
# 2         2 2022-10-12 14:29:28.945439
# 3         2 2022-10-12 14:29:28.945439
# 4         2 2022-10-12 14:29:28.945439

# %%
address_df.head()
# Out:
#    address_id               address address2  district  city_id postal_code  \
# 0           1     47 MySakila Drive     None   Alberta      300
# 1           2    28 MySQL Boulevard     None       QLD      576
# 2           3     23 Workhaven Lane     None   Alberta      300
# 3           4  1411 Lillydale Drive     None       QLD      576
# 4           5        1913 Hanoi Way           Nagasaki      463       35200
#
#          phone                last_update
# 0              2022-10-12 14:29:52.774447
# 1              2022-10-12 14:29:52.774447
# 2  14033335568 2022-10-12 14:29:52.774447
# 3   6172235589 2022-10-12 14:29:52.774447
# 4  28303384290 2022-10-12 14:29:52.774447

# %%
fact_rental1 = pd.merge(rental_df,payment_df[['rental_id','amount','payment_date']],on='rental_id', how='left')
fact_rental2= pd.merge(fact_rental1,inventory_df[['inventory_id','film_id']],on='inventory_id', how='left')
fact_rental = pd.merge(fact_rental2,store_df[['staff_id','store_id',]],on='staff_id', how='left')

# %%
fact_rental.drop(columns=['last_update'], inplace=True)

# %%
fact_rental.head()
# Out:
#    rental_id         rental_date  inventory_id  customer_id return_date  \
# 0      11496 2021-07-15 15:16:03          2047          155         NaT
# 1      12222 2021-07-15 15:16:03          3949           22         NaT
# 2      12574 2021-07-15 15:16:03           177          317         NaT
# 3      12891 2021-07-15 15:16:03          2764          388         NaT
# 4      12901 2021-07-15 15:16:03          2799          180         NaT
#
#    staff_id  amount               payment_date  store_id
# 0         1    7.98 2022-10-15 13:44:29.996577         1
# 1         1    4.99 2022-10-15 13:44:29.996577         1
# 2         2    0.99 2022-10-15 13:44:29.996577         2
# 3         2    0.99 2022-10-15 13:44:29.996577         2
# 4         2    4.99 2022-10-15 13:44:29.996577         2

# %%
dim_customer = pd.merge(customer_df,address_df,on='address_id', how='left')

# %%
# * drop the last update coloumn

# %%
dim_customer
# Out:
#      customer_id  store_id first_name last_name  \
# 0            480         1      Corey    Hauser
# 1            524         1      Jared       Ely
# 2              3         1      Linda  Williams
# 3              4         2    Barbara     Jones
# 4              5         1  Elizabeth     Brown
# ..           ...       ...        ...       ...
# 594          597         1    Freddie    Duggan
# 595          598         1       Wade  Delvalle
# 596          599         2     Austin   Cintron
# 597            1         1       Mary     Smith
# 598            2         1   Patricia   Johnson
#
#                                   email  address_id  activebool create_date  \
# 0       corey.hauser@sakilacustomer.org         485        True  2006-02-14
# 1          jared.ely@sakilacustomer.org         530        True  2006-02-14
# 2     linda.williams@sakilacustomer.org           7        True  2006-02-14
# 3      barbara.jones@sakilacustomer.org           8        True  2006-02-14
# ...

# %%
dim_film1 = pd.merge(film_df,film_category_df[['film_id','category_id']],on='film_id', how='left')

# %%
dim_film2=pd.merge(dim_film1,category_df[['category_id','name']],on='category_id', how='left')

# %%
dim_film=pd.merge(dim_film2,film_actor_df[['film_id','actor_id']],on='film_id', how='left')

# %%
dim_film.head()

# %%
actor_df.drop_duplicates(inplace = True)

# %%
count_film_by_categorey = dim_film.groupby([ 'name'])['film_id'].count().reset_index(name='count')

# %%
# 2. Which categories have most films?//

# %%
count_film_by_categorey.sort_values(by='count', ascending=False)

# %%
# . Who are the top 5 actors with most movies?

# %%
count_film_by_actor = dim_film.groupby([ 'actor_id'])['film_id'].count().reset_index(name='count')

# %%
count_film_by_actor_name = pd.merge(count_film_by_actor,actor_df[['actor_id','first_name','last_name']],on='actor_id', how='left')

# %%
count_film_by_actor_name.sort_values(by='count', ascending=False).head()
# Out:
#      actor_id  count first_name  last_name
# 106     107.0     42       Gina  Degeneres
# 101     102.0     41     Walter       Torn
# 197     198.0     40       Mary     Keitel
# 180     181.0     39    Matthew     Carrey
# 22       23.0     37     Sandra     Kilmer

# %%
# 4. Get a sorted list of movies based on number of actors.

# %%
count_actor_by_film = dim_film.groupby([ 'film_id','title'])['actor_id'].count().reset_index(name='count')

# %%
count_actor_by_film.sort_values(by='count', ascending=False)
# Out:
#      film_id              title  count
# 507      508   Lambs Cincinatti     15
# 248      249    Dracula Crystal     13
# 187      188         Crazy Home     13
# 86        87  Boondock Ballroom     13
# 145      146        Chitty Lock     13
# ..       ...                ...    ...
# 555      556       Maltese Hope      1
# 49        50    Baked Cleopatra      1
# 802      803   Slacker Liaisons      0
# 256      257   Drumline Cyclone      0
# 322      323        Flight Lies      0
#
# [1000 rows x 3 columns]

# %%
# What is the monthly trend of total sales? (by payment date)

# %%
fact_rental['month'] = fact_rental['payment_date'].dt.month.astype('Int64')
fact_rental['years'] = fact_rental['payment_date'].dt.year.astype('Int64')

# %%
fact_rental['month_year'] = fact_rental['month'].astype(str)+ fact_rental['years'].astype(str)
fact_rental['yearmonth'] = fact_rental['years'].astype(str) + '-' + fact_rental['month'].astype(str).str.zfill(2)

# %%
sum_amount_by_month_year = fact_rental.groupby([ 'yearmonth'])['amount'].sum().reset_index(name='sum')

# %%
sum_amount_by_month_year_cleaned = sum_amount_by_month_year[sum_amount_by_month_year['yearmonth'] != '<NA>-<NA>']

# %%
sum_amount_by_month_year_cleaned['yearmonth'] = pd.to_datetime(sum_amount_by_month_year_cleaned['yearmonth'], format='%Y-%m')


# Create the line plot
plt.figure(figsize=(10, 6))
sns.lineplot(x='yearmonth', y='sum', data=sum_amount_by_month_year_cleaned, marker='o')

# Customize the plot
plt.title('Monthly Sum Over Time')
plt.xlabel('Month-Year')
plt.ylabel('Sum')
plt.grid(True)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_37640\4140353855.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sum_amount_by_month_year_cleaned['yearmonth'] = pd.to_datetime(sum_amount_by_month_year_cleaned['yearmonth'], format='%Y-%m')

# %%
# Is store 1 doing better than store 2

# %%
store_sum_sale = fact_rental.groupby([ 'store_id'])['amount'].sum().reset_index(name='sum')

# %%
store_sum_sale
# Out:
#    store_id       sum
# 0         1  30489.75
# 1         2  30813.33

# %% [markdown]
# <!-- . Are there any movies that are not in the inventory? If so, how many? -->

# %%
inv_film = pd.merge(film_df,inventory_df[['film_id','store_id']],on='film_id', how='left')
inv_film

# %%
df_inv_film = inv_film[inv_film['store_id'].isna()]
df_inv_film

# %%
# 8. How many customers have not returned more than 1 DVD?

# %%
inventory_df
inventory_df.film_id.unique()

# %%
customer_dont_return=fact_rental[fact_rental['amount'].isna()]
customer_dont_return
# Out:
#       rental_id         rental_date  inventory_id  customer_id  \
# 980         972 2020-10-28 20:21:07             2          411
# 369         361 2020-10-25 07:03:28             6          587
# 1041       1033 2020-10-29 04:50:07            14           25
# 1003        995 2020-10-29 00:06:02            17          150
# 473         465 2020-10-25 20:44:36            20          261
# ...         ...                 ...           ...          ...
# 879         871 2020-10-28 05:01:30          4573          303
# 2265       2258 2020-11-16 05:30:36          4573          292
# 1092       1084 2020-10-29 11:10:17          4577           12
# 590         582 2020-10-26 11:33:46          4579          198
# 719         711 2020-10-27 03:49:03          4581          215
#
#              return_date  staff_id  amount payment_date  film_id  store_id  \
# 980  2020-11-04 00:36:07         1     NaN          NaT        1         1
# ...

# %%
movie_dont_return_by_cus= customer_dont_return.groupby([ 'customer_id'])['rental_id'].count().reset_index(name='count')
df_count_bad_cus=movie_dont_return_by_cus[movie_dont_return_by_cus['count']>1]
df_count_bad_cus
# Out:
#      customer_id  count
# 0              1      2
# 2              3      2
# 3              5      3
# 4              6      3
# 5              7      5
# ..           ...    ...
# 522          589      3
# 524          593      2
# 525          594      4
# 527          596      6
# 528          597      2
#
# [377 rows x 2 columns]

# %%
# For how long each movie have waited in the shelf? (total and average number of days between
# rentals)
f_mean=fact_rental[fact_rental['return_date'].isna()==False]
f_mean_test=f_mean.groupby([ 'film_id'])['days_on_shelf'].mean().reset_index(name='mean')
fact_rental['adjusted_rental_date'] = np.where(
    fact_rental['return_date'].isna(),
    fact_rental['rental_date'] + f_mean_test['mean'],
    fact_rental['return_date'])

# fact_rental
fact_rental['days_on_shelf']=fact_rental['adjusted_rental_date']-fact_rental['rental_date']
fact_rental.sort_values('inventory_id')
sum_days_on_shelf=fact_rental.groupby([ 'film_id'])['days_on_shelf'].sum().reset_index(name='sum')
sum_days_on_shelf
mean_days_between_rental=fact_rental.groupby([ 'film_id','inventory_id'])['days_on_shelf'].mean().reset_index(name='mean')
mean_days_between_rental
# Out:
#       film_id  inventory_id            mean
# 0           1             1 7 days 01:35:40
# 1           1             2 5 days 23:18:48
# 2           1             3 2 days 22:42:30
# 3           1             4 1 days 12:56:00
# 4           1             6 4 days 06:53:00
# ...       ...           ...             ...
# 4575     1000          4577 5 days 08:51:00
# 4576     1000          4578 4 days 00:24:00
# 4577     1000          4579 4 days 00:23:12
# 4578     1000          4580 6 days 11:17:00
# 4579     1000          4581 3 days 14:20:00
#
# [4580 rows x 3 columns]

# %%
# Get the number of times each movie which is available for rent (i.e., can be found in the inventory)
# has been rented and get its total revenue

# %%
fact_rental_cate=pd.merge(fact_rental,dim_film[['film_id','name']],on='film_id', how='left')
fact_rental_cate.head()

# %%
movie_is_avalble=fact_rental[fact_rental['film_id'].isna()]
count_rental=fact_rental.groupby([ 'film_id'])['rental_id'].count().reset_index(name='count')
sum_rental=fact_rental.groupby([ 'film_id'])['amount'].sum().reset_index(name='sum')
sum_rental_month=fact_rental_cate.groupby([ 'film_id','month','name'])['amount'].sum().reset_index(name='sum')
sum_rental
count_sum= pd.merge(sum_rental,count_rental[['film_id','count']],on='film_id', how='left')
count_rental_month=fact_rental_cate.groupby(['film_id','month','name'])['rental_id'].count().reset_index(name='count')
count_sum

# %%
# Get rental count and total revenue of movies by genre and rental month.

# %%
sum_rental_month.head(10)

# %%
count_rental_month
sum_count_by_cate_month=pd.merge(count_rental_month,sum_rental_month[['film_id','sum']],on='film_id', how='left')
count_sum_month_cate = pd.merge(count_rental_month, sum_rental_month, on=['film_id', 'month', 'name'], how='inner')
count_sum_month_cate

# %%
# For how long each movie have waited in the shelf? (total and average number of days between
# rentals)
f_mean=fact_rental[fact_rental['return_date'].isna()==False]
f_mean_test=f_mean.groupby([ 'film_id'])['days_on_shelf'].mean().reset_index(name='mean')
fact_rental['adjusted_rental_date'] = np.where(
    fact_rental['return_date'].isna(),
    fact_rental['rental_date'] + f_mean_test['mean'],
    fact_rental['return_date'])

# fact_rental
fact_rental['days_on_shelf']=fact_rental['adjusted_rental_date']-fact_rental['rental_date']
fact_rental.sort_values('inventory_id')
sum_days_on_shelf=fact_rental.groupby([ 'film_id'])['days_on_shelf'].sum().reset_index(name='sum')
sum_days_on_shelf
mean_days_between_rental=fact_rental.groupby([ 'film_id','inventory_id'])['days_on_shelf'].mean().reset_index(name='mean')
mean_days_between_rental
fact_rental.sort_values('inventory_id')

# %%
#to fix the above base on the below

# %%
fact_rental.sort_values(by=['inventory_id', 'rental_date'], inplace=True)

# Use groupby and shift to calculate the difference
fact_rental['prev_return_date'] = fact_rental.groupby('inventory_id')['return_date'].shift()

# Calculate the difference between the previous return_date and the current rental_date
fact_rental['rental_date_diff'] = fact_rental['rental_date'] - fact_rental['prev_return_date']
fact_rental

# %%
# Are movies usually returned late, early, or on time?

# %%
dim_film
fact_rental_duration=pd.merge(fact_rental,dim_film[['film_id','rental_duration']],on='film_id', how='left')
fact_rental_duration['rental_duration']=pd.to_timedelta(fact_rental_duration['rental_duration'], unit='days')
fact_rental_duration['test']=fact_rental_duration['days_on_shelf'] -fact_rental_duration['rental_duration']

fact_rental_duration['indication']= np.where(
    fact_rental_duration['rental_duration']>fact_rental_duration['days_on_shelf'],
    'ontime',
    'late')

fact_rental_duration
# Out:
#        rental_id         rental_date  inventory_id  customer_id  \
# 0           4863 2020-12-06 19:03:15             1          431
# 1           4863 2020-12-06 19:03:15             1          431
# 2           4863 2020-12-06 19:03:15             1          431
# 3           4863 2020-12-06 19:03:15             1          431
# 4           4863 2020-12-06 19:03:15             1          431
# ...          ...                 ...           ...          ...
# 88015       9701 2020-12-29 07:32:21          4581          401
# 88016       9701 2020-12-29 07:32:21          4581          401
# 88017      12894 2021-01-17 03:49:28          4581          541
# 88018      12894 2021-01-17 03:49:28          4581          541
# 88019      12894 2021-01-17 03:49:28          4581          541
#
#               return_date  staff_id  amount               payment_date  \
# 0     2020-12-09 21:29:15         2    0.99 2022-09-09 17:31:41.996577
# ...

# %%
# . In each category, which actor is the most popular among customers?

#test290724
